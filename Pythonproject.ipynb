# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\sudee\\Downloads\\Crime_Incidents_in_2024.csv") #used to read data
data.head() #used to check the first five rows of the data
# Out:
#            X          Y       CCN              REPORT_DAT     SHIFT  METHOD  \
# 0  401170.24  136698.95  24422993  2024/08/22 21:41:50+00   EVENING  OTHERS
# 1  399283.19  134605.96  24182623  2024/11/24 14:15:08+00       DAY  OTHERS
# 2  398758.71  145213.06  24180013  2024/11/20 03:13:27+00   EVENING  OTHERS
# 3  396830.43  137253.62  24184114  2024/11/27 03:55:52+00   EVENING  OTHERS
# 4  404419.52  136961.93  24181938  2024/11/24 10:29:48+00  MIDNIGHT  OTHERS
#
#        OFFENSE                                 BLOCK     XBLOCK     YBLOCK  \
# 0  THEFT/OTHER  600 - 699 BLOCK OF ELLIOTT STREET NE  401170.24  136698.95
# 1  THEFT/OTHER           1 - 69 BLOCK OF I STREET SE  399283.19  134605.96
# 2  THEFT/OTHER  100 - 199 BLOCK OF CARROLL STREET NW  398758.71  145213.06
# 3  THEFT/OTHER   1000 - 1099 BLOCK OF 16TH STREET NW  396830.43  137253.62
# 4  THEFT/OTHER  700 - 725 BLOCK OF PARKSIDE PLACE NE  404419.52  136961.93
#
# ...

# %%
data.shape #used to check the rows and columns of the data
# Out:
# (29286, 25)

# %%
data.duplicated().sum() #used to check the duplicate entries
# Out:
# np.int64(0)

# %%
data.isna().sum() #used to check the number of null entries in each column
# Out:
# X                           0
# Y                           0
# CCN                         0
# REPORT_DAT                  0
# SHIFT                       0
# METHOD                      0
# OFFENSE                     0
# BLOCK                       0
# XBLOCK                      0
# YBLOCK                      0
# WARD                        4
# ANC                         4
# DISTRICT                  745
# PSA                       468
# NEIGHBORHOOD_CLUSTER        4
# BLOCK_GROUP                13
# CENSUS_TRACT               13
# VOTING_PRECINCT             4
# LATITUDE                    0
# LONGITUDE                   0
# BID                     23874
# START_DATE                  5
# END_DATE                 2093
# OBJECTID                    0
# OCTO_RECORD_ID          29286
# dtype: int64

# %%
sb.histplot(data['DISTRICT'],kde=True)
# Out:
# <Axes: xlabel='DISTRICT', ylabel='Count'>

# %%
data['DISTRICT'].median()
# Out:
# np.float64(4.0)

# %%
mode=data['DISTRICT'].mode()[0]
mode
# Out:
# np.float64(3.0)

# %%
data['DISTRICT'].mean()
# Out:
# np.float64(3.7031288322063)

# %%
data['DISTRICT']=data['DISTRICT'].fillna(mode)
data['DISTRICT'].isna().sum()
# Out:
# np.int64(0)

# %%
sb.histplot(x= data['PSA'],kde=True)
# Out:
# <Axes: xlabel='PSA', ylabel='Count'>

# %%
print("MEAN OF PSA:",data['PSA'].mean())
modev=data['PSA'].mode()[0]
print("MODE OF PSA:",data['PSA'].mode())
print("MEDIAN OF PSA:",data['PSA'].median())
# Out:
# MEAN OF PSA: 374.8260462211118
# MODE OF PSA: 0    305.0
# Name: PSA, dtype: float64
# MEDIAN OF PSA: 401.0

# %%
data['PSA']=data['PSA'].fillna(modev)
data['PSA'].isna().sum()
# Out:
# np.int64(0)

# %%
sb.histplot(x=data['CENSUS_TRACT'],kde=True)
# Out:
# <Axes: xlabel='CENSUS_TRACT', ylabel='Count'>

# %%
print("MEAN of CENSUS_TRACT",data['CENSUS_TRACT'].mean())
print("MEDIAN of CENSUS_TRACT",data['CENSUS_TRACT'].median())
print("MODE of CENSUS_TRACT",data['CENSUS_TRACT'].mode())
# Out:
# MEAN of CENSUS_TRACT 7522.612202370786
# MEDIAN of CENSUS_TRACT 7202.0
# MODE of CENSUS_TRACT 0    8803.0
# Name: CENSUS_TRACT, dtype: float64

# %%
data['CENSUS_TRACT']=data['CENSUS_TRACT'].fillna(data['CENSUS_TRACT'].mode()[0])
data['CENSUS_TRACT'].isna().sum()
# Out:
# np.int64(0)

# %%
data['END_DATE']=data['END_DATE'].ffill()
data['END_DATE'].isna().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum()
# Out:
# X                           0
# Y                           0
# CCN                         0
# REPORT_DAT                  0
# SHIFT                       0
# METHOD                      0
# OFFENSE                     0
# BLOCK                       0
# XBLOCK                      0
# YBLOCK                      0
# WARD                        4
# ANC                         4
# DISTRICT                    0
# PSA                         0
# NEIGHBORHOOD_CLUSTER        4
# BLOCK_GROUP                13
# CENSUS_TRACT                0
# VOTING_PRECINCT             4
# LATITUDE                    0
# LONGITUDE                   0
# BID                     23874
# START_DATE                  5
# END_DATE                    0
# OBJECTID                    0
# OCTO_RECORD_ID          29286
# dtype: int64

# %%
plt.figure(figsize=(16,10))
sb.boxplot(data)
# Out:
# <Axes: >

# %%
sb.boxplot(y=data['CCN'])
# Out:
# <Axes: ylabel='CCN'>

# %%
#HANDLING OUTLIERS in CCN COLUMN
q1=np.percentile(data['CCN'],25)
q3=np.percentile(data['CCN'],75)
iqr=q3-q1
ub=q3+1.5*iqr
lb=q1-1.5*iqr
data['CCN'] = data['CCN'].apply(lambda x: lb if x < lb else ub if x > ub else x)

# %%
sb.boxplot(y=data['CCN'])
# Out:
# <Axes: ylabel='CCN'>

# %%
sb.boxplot(y=data['X'])
# Out:
# <Axes: ylabel='X'>

# %%
#HANDLING OUTLIERS in X COLUMN
q1=np.percentile(data['X'],25)
q3=np.percentile(data['X'],75)
iqr=q3-q1
ub=q3+1.5*iqr
lb=q1-1.5*iqr
data['X'] = data['X'].apply(lambda x: lb if x < lb else ub if x > ub else x)

# %%
sb.boxplot(y=data['X'])
# Out:
# <Axes: ylabel='X'>

# %%
sb.boxplot(y=data['Y'])
# Out:
# <Axes: ylabel='Y'>

# %%
#HANDLING OUTLIERS in Y COLUMN
q1=np.percentile(data['Y'],25)
q3=np.percentile(data['Y'],75)
iqr=q3-q1
ub=q3+1.5*iqr
lb=q1-1.5*iqr
data['Y'] = data['Y'].apply(lambda x: lb if x < lb else ub if x > ub else x)

# %%
sb.boxplot(y=data['Y'])
# Out:
# <Axes: ylabel='Y'>

# %%
sb.boxplot(y=data['XBLOCK'])
# Out:
# <Axes: ylabel='XBLOCK'>

# %%
#HANDLING OUTLIERS in XBLOCK COLUMN
q1=np.percentile(data['XBLOCK'],25)
q3=np.percentile(data['XBLOCK'],75)
iqr=q3-q1
ub=q3+1.5*iqr
lb=q1-1.5*iqr
data['XBLOCK'] = data['XBLOCK'].apply(lambda x: lb if x < lb else ub if x > ub else x)

# %%
sb.boxplot(y=data['XBLOCK'])
# Out:
# <Axes: ylabel='XBLOCK'>

# %%
sb.boxplot(y=data['YBLOCK'])
# Out:
# <Axes: ylabel='YBLOCK'>

# %%
#HANDLING OUTLIERS in YBLOCK COLUMN
q1=np.percentile(data['YBLOCK'],25)
q3=np.percentile(data['YBLOCK'],75)
iqr=q3-q1
ub=q3+1.5*iqr
lb=q1-1.5*iqr
data['YBLOCK'] = data['YBLOCK'].apply(lambda x: lb if x < lb else ub if x > ub else x)

# %%
sb.boxplot(y=data['YBLOCK'])
# Out:
# <Axes: ylabel='YBLOCK'>

# %%
sb.boxplot(y=data['CENSUS_TRACT'])
# Out:
# <Axes: ylabel='CENSUS_TRACT'>

# %%
#HANDLING OUTLIERS in CENSUS_TRACT COLUMN
q1=np.percentile(data['CENSUS_TRACT'],25)
q3=np.percentile(data['CENSUS_TRACT'],75)
iqr=q3-q1
ub=q3+1.5*iqr
lb=q1-1.5*iqr
data['CENSUS_TRACT'] = data['CENSUS_TRACT'].apply(lambda x: lb if x < lb else ub if x > ub else x)

# %%
sb.boxplot(y=data['CENSUS_TRACT'])
# Out:
# <Axes: ylabel='CENSUS_TRACT'>

# %%
sb.boxplot(y=data['LATITUDE'])
# Out:
# <Axes: ylabel='LATITUDE'>

# %%
#HANDLING OUTLIERS in LATITUDE COLUMN
q1=np.percentile(data['LATITUDE'],25)
q3=np.percentile(data['LATITUDE'],75)
iqr=q3-q1
ub=q3+1.5*iqr
lb=q1-1.5*iqr
data['LATITUDE'] = data['LATITUDE'].apply(lambda x: lb if x < lb else ub if x > ub else x)

# %%
sb.boxplot(y=data['LATITUDE'])
# Out:
# <Axes: ylabel='LATITUDE'>

# %%
sb.boxplot(y=data['LONGITUDE'])
# Out:
# <Axes: ylabel='LONGITUDE'>

# %%
#HANDLING OUTLIERS in LATITUDE COLUMN
q1=np.percentile(data['LONGITUDE'],25)
q3=np.percentile(data['LONGITUDE'],75)
iqr=q3-q1
ub=q3+1.5*iqr
lb=q1-1.5*iqr
data['LONGITUDE'] = data['LONGITUDE'].apply(lambda x: lb if x < lb else ub if x > ub else x)

# %%
sb.boxplot(y=data['LONGITUDE'])
# Out:
# <Axes: ylabel='LONGITUDE'>

# %%
plt.figure(figsize=(16,10))
sb.boxplot(data)
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['X', 'Y', 'CCN', 'REPORT_DAT', 'SHIFT', 'METHOD', 'OFFENSE', 'BLOCK',
#        'XBLOCK', 'YBLOCK', 'WARD', 'ANC', 'DISTRICT', 'PSA',
#        'NEIGHBORHOOD_CLUSTER', 'BLOCK_GROUP', 'CENSUS_TRACT',
#        'VOTING_PRECINCT', 'LATITUDE', 'LONGITUDE', 'BID', 'START_DATE',
#        'END_DATE', 'OBJECTID', 'OCTO_RECORD_ID'],
#       dtype='object')

# %%
data['METHOD'].unique()
# Out:
# array(['OTHERS', 'KNIFE', 'GUN'], dtype=object)

# %%
counts = data['METHOD'].value_counts()
counts
plt.pie(counts,labels=data['METHOD'].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x1ef0cb0d450>,
# ...
#  [Text(-1.0577189658222763, 0.3020440188778029, 'OTHERS'),
#   Text(1.0431542235705713, -0.34904049313350255, 'KNIFE'),
#   Text(1.0988996405232974, -0.04918922704991696, 'GUN')])

# %%
selected_district = int(input("Enter a district number (e.g., 1 to 7): "))
filtered_df = data[data['DISTRICT'] == selected_district]
plt.figure(figsize=(10, 6))
sb.countplot(data=filtered_df, x='OFFENSE')
plt.title(f"Crime Types in District {selected_district}")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Enter a district number (e.g., 1 to 7):  3

# %%
plt.figure(figsize=(14, 7))
sb.countplot(data=data, x='DISTRICT', hue='OFFENSE')
plt.title("Crime Types by District")
plt.xlabel("District")
plt.ylabel("Number of Crimes")
plt.legend(title='Offense Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sb.scatterplot(data=data, x='LONGITUDE', y='LATITUDE', hue='OFFENSE', alpha=0.5)
plt.title("Geographic Distribution of Crimes")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.legend(title='Offense', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
data1=data[['CCN','XBLOCK','YBLOCK','WARD','DISTRICT','PSA','CENSUS_TRACT','LATITUDE','LONGITUDE','OBJECTID']]
data1
# Out:
#                 CCN     XBLOCK        YBLOCK  WARD  DISTRICT    PSA  \
# 0      2.432790e+07  401170.24  136698.95000   6.0       1.0  104.0
# 1      2.418262e+07  399283.19  134605.96000   6.0       1.0  106.0
# 2      2.418001e+07  398758.71  145189.27747   4.0       4.0  401.0
# 3      2.418411e+07  396830.43  137253.62000   2.0       2.0  207.0
# 4      2.418194e+07  404419.52  136961.93000   7.0       6.0  601.0
# ...             ...        ...           ...   ...       ...    ...
# 29281  2.406394e+07  396842.65  142206.68000   4.0       4.0  404.0
# 29282  2.406480e+07  399690.03  138139.17000   5.0       5.0  502.0
# 29283  2.406852e+07  405450.10  137846.80000   7.0       6.0  602.0
# 29284  2.407006e+07  395175.22  140861.92000   3.0       2.0  203.0
# 29285  2.407041e+07  398758.71  145189.27747   4.0       4.0  401.0
#
#        CENSUS_TRACT   LATITUDE  LONGITUDE   OBJECTID
# 0            8001.0  38.898140 -76.986510  703627758
# ...

# %%
data1.cov()
# Out:
#                        CCN        XBLOCK        YBLOCK          WARD  \
# CCN           6.802460e+09 -2.064522e+07  7.404921e+06 -14329.479210
# XBLOCK       -2.064522e+07  9.174229e+06 -4.531633e+06   5120.315093
# YBLOCK        7.404921e+06 -4.531633e+06  1.027572e+07  -4492.871065
# WARD         -1.432948e+04  5.120315e+03 -4.492871e+03      5.395268
# DISTRICT     -1.617399e+04  3.396241e+03 -1.673799e+03      2.179695
# PSA          -1.576875e+06  3.422163e+05 -1.704450e+05    219.054206
# CENSUS_TRACT -1.194394e+07  6.230574e+06 -5.452535e+06   4208.022985
# LATITUDE      6.671296e+01 -4.081950e+01  9.256192e+01     -0.040472
# LONGITUDE    -2.380126e+02  1.057790e+02 -5.225740e+01      0.059034
# OBJECTID      1.953018e+08 -5.008378e+06  6.912472e+05  -2788.303894
#
#                   DISTRICT           PSA  CENSUS_TRACT   LATITUDE   LONGITUDE  \
# CCN          -16173.994548 -1.576875e+06 -1.194394e+07  66.712956 -238.012563
# ...

# %%
data1.corr()
# Out:
#                    CCN    XBLOCK    YBLOCK      WARD  DISTRICT       PSA  \
# CCN           1.000000 -0.082642  0.028008 -0.074795 -0.107633 -0.104757
# XBLOCK       -0.082642  1.000000 -0.466728  0.727739  0.615425  0.619065
# YBLOCK        0.028008 -0.466728  1.000000 -0.603563 -0.286588 -0.291339
# WARD         -0.074795  0.727739 -0.603563  1.000000  0.515133  0.516815
# DISTRICT     -0.107633  0.615425 -0.286588  0.515133  1.000000  0.993752
# PSA          -0.104757  0.619065 -0.291339  0.516815  0.993752  1.000000
# CENSUS_TRACT -0.045404  0.644940 -0.533296  0.567984  0.368462  0.371450
# LATITUDE      0.028012 -0.466720  1.000000 -0.603580 -0.286617 -0.291367
# LONGITUDE    -0.082633  1.000000 -0.466796  0.727704  0.615357  0.618998
# OBJECTID      0.023168 -0.016178  0.002110 -0.011744 -0.023781 -0.023091
#
#               CENSUS_TRACT  LATITUDE  LONGITUDE  OBJECTID
# CCN              -0.045404  0.028012  -0.082633  0.023168
# ...

# %%
plt.figure(figsize=(16,10))
sb.heatmap(data1.corr(),annot=True)
# Out:
# <Axes: >

# %%
data1.columns
# Out:
# Index(['CCN', 'XBLOCK', 'YBLOCK', 'WARD', 'DISTRICT', 'PSA', 'CENSUS_TRACT',
#        'LATITUDE', 'LONGITUDE', 'OBJECTID'],
#       dtype='object')

# %%
CTD=['XBLOCK','YBLOCK']
data1=data1.drop(columns=CTD,axis=1)
data1
# Out:
#                 CCN  WARD  DISTRICT    PSA  CENSUS_TRACT   LATITUDE  \
# 0      2.432790e+07   6.0       1.0  104.0        8001.0  38.898140
# 1      2.418262e+07   6.0       1.0  106.0        7202.0  38.879286
# 2      2.418001e+07   4.0       4.0  401.0        1702.0  38.974587
# 3      2.418411e+07   2.0       2.0  207.0       10100.0  38.903132
# 4      2.418194e+07   7.0       6.0  601.0        9602.0  38.900499
# ...             ...   ...       ...    ...           ...        ...
# 29281  2.406394e+07   4.0       4.0  404.0        2600.0  38.947751
# 29282  2.406480e+07   5.0       5.0  502.0        8702.0  38.911115
# 29283  2.406852e+07   7.0       6.0  602.0        9601.0  38.908464
# 29284  2.407006e+07   3.0       2.0  203.0        1304.0  38.935629
# 29285  2.407041e+07   4.0       4.0  401.0        1702.0  38.974587
#
#        LONGITUDE   OBJECTID
# 0     -76.986510  703627758
# 1     -77.008261  703627760
# 2     -77.014325  703627761
# 3     -77.036541  703627762
# ...

# %%
data1.corr()
# Out:
#                    CCN      WARD  DISTRICT       PSA  CENSUS_TRACT  LATITUDE  \
# CCN           1.000000 -0.074795 -0.107633 -0.104757     -0.045404  0.028012
# WARD         -0.074795  1.000000  0.515133  0.516815      0.567984 -0.603580
# DISTRICT     -0.107633  0.515133  1.000000  0.993752      0.368462 -0.286617
# PSA          -0.104757  0.516815  0.993752  1.000000      0.371450 -0.291367
# CENSUS_TRACT -0.045404  0.567984  0.368462  0.371450      1.000000 -0.533241
# LATITUDE      0.028012 -0.603580 -0.286617 -0.291367     -0.533241  1.000000
# LONGITUDE    -0.082633  0.727704  0.615357  0.618998      0.645063 -0.466788
# OBJECTID      0.023168 -0.011744 -0.023781 -0.023091     -0.004279  0.002112
#
#               LONGITUDE  OBJECTID
# CCN           -0.082633  0.023168
# WARD           0.727704 -0.011744
# DISTRICT       0.615357 -0.023781
# PSA            0.618998 -0.023091
# CENSUS_TRACT   0.645063 -0.004279
# LATITUDE      -0.466788  0.002112
# ...

# %%
sb.heatmap(data1.corr(),annot=True)
# Out:
# <Axes: >

# %%
sb.lineplot(x='DISTRICT',y='PSA',data=data1)
# Out:
# <Axes: xlabel='DISTRICT', ylabel='PSA'>

# %%
sb.barplot(x='DISTRICT',y='PSA',hue='DISTRICT',data=data1)
# Out:
# <Axes: xlabel='DISTRICT', ylabel='PSA'>

# %%
sb.pairplot(data1)

# %%
data
# Out:
#                X            Y           CCN              REPORT_DAT     SHIFT  \
# 0      401170.24  136698.9500  2.432790e+07  2024/08/22 21:41:50+00   EVENING
# 1      399283.19  134605.9600  2.418262e+07  2024/11/24 14:15:08+00       DAY
# 2      398758.71  145189.2775  2.418001e+07  2024/11/20 03:13:27+00   EVENING
# 3      396830.43  137253.6200  2.418411e+07  2024/11/27 03:55:52+00   EVENING
# 4      404419.52  136961.9300  2.418194e+07  2024/11/24 10:29:48+00  MIDNIGHT
# ...          ...          ...           ...                     ...       ...
# 29281  396842.65  142206.6800  2.406394e+07  2024/04/29 18:17:16+00       DAY
# 29282  399690.03  138139.1700  2.406480e+07  2024/05/11 18:22:53+00       DAY
# 29283  405450.10  137846.8000  2.406852e+07  2024/05/07 18:29:18+00       DAY
# 29284  395175.22  140861.9200  2.407006e+07  2024/05/10 15:26:11+00       DAY
# 29285  398758.71  145189.2775  2.407041e+07  2024/05/11 03:02:41+00  MIDNIGHT
#
# ...

# %%
data1.columns
# Out:
# Index(['CCN', 'WARD', 'DISTRICT', 'PSA', 'CENSUS_TRACT', 'LATITUDE',
#        'LONGITUDE', 'OBJECTID'],
#       dtype='object')

# %%
#CHI2 TEST
from scipy import stats
g1=np.array(data1['PSA'])
g2=np.array(data1['DISTRICT'])
t_test_stat,pvalue=stats.ttest_ind(g1,g2)
print(t_test_stat,pvalue)
alpha=0.05
if pvalue<alpha:
    print('rej the hypo')
else:
    print('unable to rej null hypo')
# Out:
# 346.94427133113555 0.0
# rej the hypo
